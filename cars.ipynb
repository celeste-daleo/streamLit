# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import numpy as np

# %%
link = 'https://raw.githubusercontent.com/murpi/wilddata/master/quests/cars.csv'

cars =  pd.read_csv(link)

# %%
cars.head(3)
# Out:
#     mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year continent
# 0  14.0          8          350  165       4209          12  1972       US.
# 1  31.9          4           89   71       1925          14  1980   Europe.
# 2  17.0          8          302  140       3449          11  1971       US.

# %%
cars['continent'] = cars['continent'].str.strip()
cars['continent'] = cars['continent'].str.replace(".", "")
# Out:
# /var/folders/ch/vbngt5w11_57bxmvvnk7pw380000gn/T/ipykernel_31188/1914507188.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   cars['continent'] = cars['continent'].str.replace(".", "")

# %%
cars['continent'].unique()
# Out:
# array(['US', 'Europe', 'Japan'], dtype=object)

# %%
sns.heatmap(cars.corr());

# %%
sns.displot(cars, x="mpg")

# %%
cars_selected = cars[cars['continent'] == 'US']
cars_selected
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year continent
# 0    14.0          8          350  165       4209          12  1972        US
# 2    17.0          8          302  140       3449          11  1971        US
# 3    15.0          8          400  150       3761          10  1971        US
# 4    30.5          4           98   63       2051          17  1978        US
# 5    23.0          8          350  125       3900          17  1980        US
# ..    ...        ...          ...  ...        ...         ...   ...       ...
# 254  23.5          6          173  110       2725          13  1982        US
# 256  17.0          8          305  130       3840          15  1980        US
# 258  22.0          6          232  112       2835          15  1983        US
# 259  18.0          6          232  100       3288          16  1972        US
# 260  22.0          6          250  105       3353          15  1977        US
#
# [162 rows x 8 columns]
